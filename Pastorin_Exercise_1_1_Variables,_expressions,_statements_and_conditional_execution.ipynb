# %% [markdown]
# <a href="https://colab.research.google.com/github/qcjpastorin01-sudo/CPE310-IE22S1/blob/main/Pastorin_Exercise_1_1_Variables%2C_expressions%2C_statements_and_conditional_execution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Exercise 1.1 Variables, expressions, statements and conditional execution**
# ---
# **Name:** Pastorin, Clara Joy M. <br>
# **Course & Section:** CPE 310 | IE22S1 <br>
# **Course Name:** Fundamentals of Data Science <br>
# **Date:** January 15, 2025 <br>

# %% [markdown]
# # Part 1: Variables, Expressions, and Statements

# %% [markdown]
# ***Exercise 2:*** Write a program that uses input to prompt a user for their name and then welcomes them.

# %%
name = input("Enter Your Name: ")
print("Hello " + name + str(", Welcome !"))
# Out:
# Enter Your Name: CY
# Hello CY, Welcome !

# %% [markdown]
# ***Exercise 3:*** Write a program to prompt the user for hours and rate per hour to compute gross pay.

# %%
hours = float(input("Enter Hours: "))
rate = float(input("Enter Rate: "))
pay = hours * rate
print("Pay: ", pay)
# Out:
# Enter Hours: 14
# Enter Rate: 3.5
# Pay:  49.0

# %% [markdown]
# ***Exercise 4:*** Assume that we execute the following assignment statements:

# %%
width = 17
height = 12.0

no1 = width//2
no2 = width/2.0
no3 = height/3
no4 = 1 + 2 * 5

if type(no1) == int:
  print('Data:  ', no1, ' | Type: Integer')
else:
  print('Data: ', no1, '| Type: Float')

if type(no2) == int:
  print('Data: ', no2, '| Type: Integer')
else:
  print('Data: ', no2, '| Type: Float')

if type(no3) == int:
  print('Data: ', no3, '| Type: Integer')
else:
  print('Data: ', no3, '| Type: Float')

if type(no3) == int:
  print('Data: ', no3, '| Type: Integer')
else:
  print('Data: ', no3, '| Type: Float')
# Out:
# Data:   8  | Type: Integer
# Data:  8.5 | Type: Float
# Data:  4.0 | Type: Float
# Data:  4.0 | Type: Float

# %% [markdown]
# ***Exercise 5:*** Write a program which prompts the user for a Celsius temperature, convert the temperature to Fahrenheit, and print out the converted temperature.

# %%
inp = input ("Enter Celsius Temperature: ")
cel = float(inp)
fahr = (cel * 9/5) + 32
print ("Termpareture in Fahrenheit: ", fahr)
# Out:
# Enter Celsius Temperature: 25
# Termpareture in Fahrenheit:  77.0

# %% [markdown]
# # Part 2: Conditional Execution

# %% [markdown]
# ***Exercise 1:*** Rewrite your pay computation to give the employee 1.5 times the hourly rate for hours worked above 40 hours.

# %%
hour = input("Enter Working Hours: ")
rate = input("Enter Rate: ")
h = float(hour)
r = float(rate)

if h > 40:
  pay = 40 * r + (h - 40) * r * 1.5
else:
  pay = h * r
print("Pay:", pay)
# Out:
# Enter Working Hours: 45
# Enter Rate: 10
# Pay: 475.0

# %% [markdown]
# ***Exercise 2:*** Rewrite your pay program using try and except so that your program handles non-numeric input gracefully by printing a message and exiting the program.

# %%
hour = input("Enter Working Hours: ")
rate = input("Enter Rate: ")
try:
  h = float(hour)
  r = float(rate)

  if h > 40:
        pay = 40 * r + (h - 40) * r * 1.5
  else:
        pay = h * r
  print("Pay: ", pay)
except:
  print("Error, please enter numeric input")
# Out:
# Enter Working Hours: 20
# Enter Rate: nine
# Error, please enter numeric input

# %% [markdown]
# ***Exercise 3:*** Write a program to prompt for a score between 0.0 and 1.0. If the score is out of range, print an error message. If the score is between 0.0 and 1.0, print a grade using the following table:

# %%
score1 = input("Enter score between 0.0 and 1.0: ")

try:
  score2 = float(score1)

  if score2 < 0.0 or score2 > 1.0:
    print("Error: Score is out of range.")
  else:
    if score2 >= 0.9:
      grade = "A"
    elif score2 >= 0.8:
      grade = "B"
    elif score >= 0.7:
      grade = "C"
    elif score >= 0.6:
      grade = "D"
    else:
      grade2 = "F"

    print("Grade: ", grade)

except:
  print("Error: Please enter a numeric value.")
# Out:
# Enter score between 0.0 and 1.0: 0.95
# Grade:  A
